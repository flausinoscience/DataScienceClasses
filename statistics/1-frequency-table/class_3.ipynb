# %% [markdown]
# # Graphical Representations of Frequency Tables
#
# Depending on the **variable type** (categorical, discrete, countinous), there are different ways of representing them.
#
# ## Categorical variables
